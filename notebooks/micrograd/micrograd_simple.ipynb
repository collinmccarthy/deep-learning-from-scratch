# %%
from dl_scratch.micrograd.test import run_value_example_tanh, run_value_example_tanh_with_exp
from dl_scratch.micrograd.utils import draw_dot

# %%
o, _x1, _w1, _x2, _w2 = run_value_example_tanh()
draw_dot(o)

# %%
o, _x1, _w1, _x2, _w2 = run_value_example_tanh_with_exp()
draw_dot(o)
